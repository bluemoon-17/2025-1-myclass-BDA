# %% [markdown]
# <a href="https://colab.research.google.com/github/bluemoon-17/2025-1-myclass-BDA/blob/main/inclass/09w_B_wed_0430_easy_ch07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9주차 수업

# %% [markdown]
# ## 결측값 제거하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({'sex' : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(axis=0)
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(subset = ['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df.dropna(subset = ['score'], axis=0)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df.dropna(subset = ['score'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-60d52e33e6ed> in <cell line: 0>()
# ----> 1 df.dropna(subset = ['score'], axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#
# KeyError: ['score']

# %%
df_nomiss = df.dropna(subset = ['score'])
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df_nomiss = df.dropna(subset = ['score', 'sex'])
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.score.mean()
# Out:
# np.float64(4.0)

# %%
df['score'].sum()
# Out:
# np.float64(16.0)

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %%
df = pd.DataFrame({'name' : ['Alfred', 'Batman', 'Catwoman'],
                   'toy' : [np.nan, 'Batmobile', 'Bullwhip'],
                   'born' : [np.nan, pd.Timestamp('1940-04-25'),
                             pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(axis='columns')
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(how='any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=2)
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=1)
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=3)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(subset = ['name', 'toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset = ['toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset = ['born'])
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df1 = pd.DataFrame(index = ['row', 'row2', 'row3'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [row, row2, row3]

# %%
df1.empty
# Out:
# True

# %%
df2 = pd.DataFrame(columns = ['col', 'col2', 'col3'])
df2
# Out:
# Empty DataFrame
# Columns: [col, col2, col3]
# Index: []

# %%
df2.empty
# Out:
# True

# %%
df3 = pd.DataFrame(index = ['row1', 'row2', 'row3'], columns = ['col1', 'col2', 'col3'])
df3
# Out:
#      col1 col2 col3
# row1  NaN  NaN  NaN
# row2  NaN  NaN  NaN
# row3  NaN  NaN  NaN

# %%
df3.empty
# Out:
# False

# %%
df4 = pd.DataFrame(np.nan,
                   index = ['row1', 'row2', 'row3'],
                   columns = ['col1', 'col2', 'col3'])
df4
# Out:
#       col1  col2  col3
# row1   NaN   NaN   NaN
# row2   NaN   NaN   NaN
# row3   NaN   NaN   NaN

# %%
df4.empty
# Out:
# False

# %%
df5 = pd.DataFrame(2,
                   index = ['row1', 'row2', 'row3'],
                   columns = ['col1', 'col2', 'col3'])
df5
# Out:
#       col1  col2  col3
# row1     2     2     2
# row2     2     2     2
# row3     2     2     2

# %%
df5.empty
# Out:
# False

# %% [markdown]
# ## 결측 값 대체

# %%
import os
os.system("git clone https://github.com/ai7dnn/data")
# Out:
# 0

# %%
exam = pd.read_csv('data/exam.csv')
exam.loc[[2, 7, 14], ['math']] = np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   NaN       86       78
# 7    8       2   NaN       78       25
# 14  15       4   NaN       56       78

# %% [markdown]
# ### 결측값 채워넣기 fillna()

# %%
exam['math'] = exam['math'].fillna(100)
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  100.0       86       78
# 7    8       2  100.0       78       25
# 14  15       4  100.0       56       78

# %%
exam.loc[[2, 7, 14], ['math']] = np.nan
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   NaN       86       78
# 7    8       2   NaN       78       25
# 14  15       4   NaN       56       78

# %%
exam['math'] = exam['math'].fillna(exam['math'].mean())
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass       math  english  science
# 2    3       1  55.235294       86       78
# 7    8       2  55.235294       78       25
# 14  15       4  55.235294       56       78

# %%
pd.set_option('display.precision', 2)
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  55.24       86       78
# 7    8       2  55.24       78       25
# 14  15       4  55.24       56       78

# %%
exam.math.isna().sum()
# Out:
# np.int64(0)

# %%
df = pd.DataFrame({'sex' : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_index()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_values()
# Out:
# sex
# 3    1
# 2    2
# 1    3
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
df['score'].value_counts().sort_index()
# Out:
# score
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
df['score'].value_counts().sort_values()
# Out:
# score
# 5    1
# 3    1
# 2    1
# 6    1
# 4    2
# Name: count, dtype: int64

# %%
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
df['score'] = np.where(df['score'] > 5, np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df.dropna(subset = ['sex', 'score'])
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 4  2.0    2.0

# %%
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame([1])
df
# Out:
#    0
# 0  1

# %%
df = pd.DataFrame([1, 1, 2, 2])
df
# Out:
#    0
# 0  1
# 1  1
# 2  2
# 3  2

# %%
df = pd.DataFrame([[1, 1, 2, 2]])
df
# Out:
#    0  1  2  3
# 0  1  1  2  2

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 10, np.nan)
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = pd.DataFrame({'x1': [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', np.nan)
df
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# <ipython-input-72-32b9c682c730> in <cell line: 0>()
#       1 df = pd.DataFrame({'x1': [1, 1, 2, 2]})
# ----> 2 df['x2'] = np.where(df['x1'] == 1, 'a', np.nan)
#       3 df
#
# DTypePromotionError: The DType <class 'numpy.dtypes.StrDType'> could not be promoted by <class 'numpy.dtypes._PyFloatDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes._PyFloatDType'>)

# %%
df = pd.DataFrame({'x1': [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', None)
df
# Out:
#    x1    x2
# 0   1     a
# 1   1     a
# 2   2  None
# 3   2  None

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      int64
#  1   x2      2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df = pd.DataFrame({'x1': [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  etc
# 3   2  etc

# %%
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  NaN
# 3   2  NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = df.fillna(10)
df
# Out:
#    x1  x2
# 0   1   a
# 1   1   a
# 2   2  10
# 3   2  10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      int64
#  1   x2      4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
type(df.loc[2, 'x2'])
# Out:
# int

# %%
type(df.loc[0, 'x2'])
# Out:
# str

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(5)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 83          ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4   14   17
# 14          audi       a4 quattro    3.1  2008    6  manual(m6)   4   15   25
# 217   volkswagen            jetta    2.5  2008    5    auto(s6)   f   21   29
# 224   volkswagen       new beetle    2.0  1999    4    auto(l4)   f   19   26
# 152       nissan   pathfinder 4wd    4.0  2008    6    auto(l5)   4   14   20
#
#     fl    category
# 83   r      pickup
# 14   p     compact
# 217  r     compact
# 224  r  subcompact
# 152  p         suv

# %%
mpg.describe()
# Out:
#         displ     year     cyl     cty     hwy
# count  234.00   234.00  234.00  234.00  234.00
# mean     3.47  2003.50    5.89   16.86   23.44
# std      1.29     4.51    1.61    4.26    5.95
# min      1.60  1999.00    4.00    9.00   12.00
# 25%      2.40  1999.00    4.00   14.00   18.00
# 50%      3.30  2003.50    6.00   17.00   24.00
# 75%      4.60  2008.00    8.00   19.00   27.00
# max      7.00  2008.00    8.00   35.00   44.00

# %%
# %config InlineBackend.figure_format = 'retina

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
sns.boxplot(data = mpg, x = 'hwy')
# Out:
# <Axes: xlabel='hwy'>

# %% [markdown]
# ### 박스상자의 구성요소

# %%
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.quantile()
# Out:
# np.float64(3.0)

# %%
s.quantile(.5)
# Out:
# np.float64(3.0)

# %%
s.quantile([.1, .2, .25, .5, .75])
# Out:
# 0.10    1.4
# 0.20    1.8
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# dtype: float64

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg.hwy.quantile([.25, .5, .75])
# Out:
# 0.25    18.0
# 0.50    24.0
# 0.75    27.0
# Name: hwy, dtype: float64

# %%
a, b = [10, 20]

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
p25, p50, p75 = mpg.hwy.quantile([.25, .5, .75])

# %%
p25
# Out:
# 18.0

# %%
p50
# Out:
# 24.0

# %%
p75
# Out:
# 27.0

# %%
iqr = p75 - p25
iqr
# Out:
# 9.0

# %%
# upper fence
UF = p75 + 1.5 * iqr
UF
# Out:
# 40.5

# %%
# lower fence
LF = p25 - 1.5 * iqr
LF
# Out:
# 4.5

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg.hwy.describe()['50%']
# Out:
# np.float64(24.0)

# %%
mpg[ mpg.hwy > UF ][['hwy']]
# Out:
#      hwy
# 212   44
# 221   44
# 222   41

# %%
mpg[ mpg.hwy > UF ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg[ mpg.hwy < LF ]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, category]
# Index: []

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
mpg[ (mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5) ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg[ (mpg['hwy'] < LF) | (mpg['hwy'] > UF) ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg['hwy'] = np.where((mpg.hwy < LF) | (mpg.hwy > UF), np.nan, mpg['hwy'])
mpg.hwy.isna().sum()
# Out:
# np.int64(3)

# %%
mpg[ mpg.hwy.isna() ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33  NaN  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35  NaN  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29  NaN  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
len(mpg)
# Out:
# 234

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 231

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %%
mpg.groupby('drv').agg(mean_hwy = ('hwy' , 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       28.16
# r       21.00

# %%
mpg[ (mpg['hwy'] < LF) | (mpg['hwy'] > UF) ]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %% [markdown]
# # END
